# %% [markdown]
# Creating a simple folium map which is one of the tool i will be using for my project
#
# folium builds on the data wrangling strengths of the Python ecosystem and the mapping strengths of the leaflet.js library. Manipulate your data in Python, then visualize it in on a Leaflet map via folium

# %% [markdown]
# In this project the Norwegian wells will be displayed and with a map marker

# %% [markdown]
# Folium and pandas are imported

# %%
import folium
import pandas as pd

# %% [markdown]
# A connection to the csv file is made and accessed with pandas

# %%
df = pd.read_csv('C:\\Users\\Leo\\Downloads\\wellboreExplorationAll.csv', 
                  usecols=['wlbWellboreName', 'wlbNsDecDeg', 'wlbEwDesDeg', 
                            'wlbPurposePlanned', 'wlbCompletionYear'])

# Renaming columns
df.columns = ['Well Name', 'Purpose', 'Completion Year', 'Latitude', 'Longitude']

# %% [markdown]
# The csv file is initialized via the variable 'df'

# %%
df
# Out:
#       Well Name  Purpose  Completion Year   Latitude  Longitude
# 0         1/2-1  WILDCAT             1989  56.887519   2.476583
# 1         1/2-2  WILDCAT             2006  56.992222   2.496572
# 2         1/3-1  WILDCAT             1968  56.855833   2.851389
# 3         1/3-2  WILDCAT             1969  56.936111   2.750000
# 4         1/3-3  WILDCAT             1983  56.952378   2.981681
# ...         ...      ...              ...        ...        ...
# 2056  7324/10-1  WILDCAT             1989  73.163736  24.313228
# 2057   7325/1-1  WILDCAT             2014  73.913528  25.116714
# 2058   7325/4-1  WILDCAT             2017  73.649319  25.178261
# 2059   7335/3-1  WILDCAT             2019  73.997183  35.837147
# 2060  7435/12-1  WILDCAT             2017  74.071725  35.808628
#
# [2061 rows x 5 columns]

# %% [markdown]
# The Folium map is created. Markers and colours are added

# %%
# Set up the colours based on well's purpose
purpose_colour = {'WILDCAT':'red', 'APPRAISAL':'green', 'WILDCAT-CCS':'blue'}

map = folium.Map(location=[df.Latitude.mean(), df.Longitude.mean()], 
                 zoom_start=3, control_scale=True)

#Loop through each row in the dataframe
for i,row in df.iterrows():
    #Setup the content of the popup
    iframe = folium.IFrame(f'Well Name: {str(row["Well Name"])} \n Purpose: {str(row["Purpose"])}')
    
    #Initialise the popup using the iframe
    popup = folium.Popup(iframe, min_width=300, max_width=300)
    
    try:
        icon_color = purpose_colour[row['Purpose']]
    except:
        #Catch nans
        icon_color = 'gray'
    
    #Add each row to the map
    folium.Marker(location=[row['Latitude'],row['Longitude']],
                  popup = popup, 
                  icon=folium.Icon(color=icon_color, icon='')).add_to(map)

# %% [markdown]
# When we run this and call upon our map object, we get the following map back with all of the locations of the offshore Norwegian wells.

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_95b7d789feaab614adf49c1014c14992 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_95b7d789feaab614adf49c1014c14992&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_95b7d789feaab614adf49c1014c14992 = L.map(
#                 &quot;map_95b7d789feaab614adf49c1014c14992&quot;,
#                 {
#                     center: [61.65358963076177, 5.304294005337216],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_95b7d789feaab614adf49c1014c14992);
#
#
#
#
#
#             var tile_layer_9339677f8f21189c78892c947863d1e4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_95b7d789feaab614adf49c1014c14992);
#
#
#             var marker_9c673460e4db34a7fa56621b500719ca = L.marker(
#                 [56.887519, 2.476583],
#                 {}
#             ).addTo(map_95b7d789feaab614adf49c1014c14992);
#
#
#             var icon_4706f9fd1126997a5b45d61f406925a4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9c673460e4db34a7fa56621b500719ca.setIcon(icon_4706f9fd1126997a5b45d61f406925a4);
#
#
#         var popup_ca252df1faa9780230429b1f9ecb3101 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_a75dbcfccf90d352ac71cfcbaa8c9485 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBXZWxsIE5hbWU6IDEvMi0xIAogUHVycG9zZTogV0lMRENBVA==&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_ca252df1faa9780230429b1f9ecb3101.setContent(i_frame_a75dbcfccf90d352ac71cfcbaa8c9485);
#
#
#
#         marker_9c673460e4db34a7fa56621b500719ca.bindPopup(popup_ca252df1faa9780230429b1f9ecb3101)
#         ;
#
#
#
#
#             var marker_9cbc3d4dfa7b6dc57aedc9f370ef45de = L.marker(
#                 [56.992222, 2.496572],
#                 {}
#             ).addTo(map_95b7d789feaab614adf49c1014c14992);
#
#
#             var icon_d60fa87b9e1ee5a06fc6a4225176840f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9cbc3d4dfa7b6dc57aedc9f370ef45de.setIcon(icon_d60fa87b9e1ee5a06fc6a4225176840f);
#
#
#         var popup_1b26ab2f1a8fd5d1750bba1237faea3a = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_4c05a9e49be1a8f70014b994d7082474 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBXZWxsIE5hbWU6IDEvMi0yIAogUHVycG9zZTogV0lMRENBVA==&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_1b26ab2f1a8fd5d1750bba1237faea3a.setContent(i_frame_4c05a9e49be1a8f70014b994d7082474);
#
#
#
#         marker_9cbc3d4dfa7b6dc57aedc9f370ef45de.bindPopup(popup_1b26ab2f1a8fd5d1750bba1237faea3a)
#         ;
#
#
#
#
#             var marker_de0935949a6c1f3c1f662451e56deebb = L.marker(
#                 [56.855833, 2.851389],
#                 {}
#             ).addTo(map_95b7d789feaab614adf49c1014c14992);
#
#
#             var icon_707b2800bde1bc02f7f47fbc3b4d4e09 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_de0935949a6c1f3c1f662451e56deebb.setIcon(icon_707b2800bde1bc02f7f47fbc3b4d4e09);
#
#
#         var popup_275970529d08cd10188c784d8c5a6637 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_c2686bc1f2460b55fe4a20f04359fd17 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;c

# %% [markdown]
# RESOURCES
#
# https://towardsdatascience.com/folium-mapping-displaying-markers-on-a-map-6bd56f3e3420#:~:text=Adding%20a%20Single%20Marker%20to,and%20longitude%20of%20our%20data.

# %%
DOCMENTATION

Folium: https://python-visualization.github.io/folium/

Pandas: https://pandas.pydata.org/docs/user_guide/index.html
